# %% [markdown]
# ### Exploratory Data Analysis (EDA)
#
# Exploratory Data Analysis (EDA) is the process of examining datasets to summarize their main characteristics, often with visual methods. It helps uncover patterns, detect anomalies, test assumptions, and build intuition before formal modeling.

# %% [markdown]
# #### 1. Import Libraries and Generate Synthetic Data
#
# Starting with data import and generation, you prepare your environment. Import necessary libraries like pandas, NumPy, Matplotlib, and Seaborn. Synthetic data is generated here to simulate a real dataset including numerical and categorical features, and some missing values to mimic common data issues.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generate synthetic dataset
np.random.seed(42)
data = pd.DataFrame({
    'age': np.random.randint(18, 70, 100),
    'salary': np.random.normal(50000, 15000, 100).round(0),
    'department': np.random.choice(['HR', 'Tech', 'Sales'], 100),
    'satisfaction': np.random.uniform(1, 5, 100).round(1)
})
# Introduce missing values
data.loc[np.random.choice(data.index, 10), 'salary'] = np.nan

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### 2. Data Inspection
#
# Explore the structure and contents of your data with basic methods. `.head()` shows the first rows, `.info()` gives datatype and null info, and `.describe()` summarizes statistics of numeric data.

# %%
data.head(5)
# Out:
#    age   salary department  satisfaction
# 0   56  21865.0       Tech           3.3
# 1   69  29498.0      Sales           1.4
# 2   46  59545.0      Sales           3.5
# 3   32  36399.0       Tech           5.0
# 4   60  57141.0         HR           1.6
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['salary'].plot(kind='hist', bins=20, title='salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['satisfaction'].plot(kind='hist', bins=20, title='satisfaction')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_15.groupby('department').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16.plot(kind='scatter', x='age', y='salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17.plot(kind='scatter', x='salary', y='satisfaction', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_18['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['salary'].plot(kind='line', figsize=(8, 4), title='salary')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_20['satisfaction'].plot(kind='line', figsize=(8, 4), title='satisfaction')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_21['department'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_21, x='age', y='department', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_22['department'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_22, x='salary', y='department', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_23['department'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_23, x='satisfaction', y='department', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_24['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['salary'].plot(kind='hist', bins=20, title='salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27['satisfaction'].plot(kind='hist', bins=20, title='satisfaction')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_28.groupby('department').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_29.plot(kind='scatter', x='index', y='age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_30.plot(kind='scatter', x='age', y='salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_31.plot(kind='scatter', x='salary', y='satisfaction', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_32.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('department')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='department', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['salary']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_33.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('department')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='department', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('salary')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['satisfaction']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_34.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('department')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='department', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('satisfaction')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_35.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('department')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='department', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_36['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38['salary'].plot(kind='line', figsize=(8, 4), title='salary')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_39['satisfaction'].plot(kind='line', figsize=(8, 4), title='satisfaction')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_40['department'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_40, x='index', y='department', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_41['department'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_41, x='age', y='department', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_42['department'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_42, x='salary', y='department', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_43['department'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_43, x='satisfaction', y='department', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           100 non-null    int64
#  1   salary        91 non-null     float64
#  2   department    100 non-null    object
#  3   satisfaction  100 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.3+ KB

# %%
data.describe()
# Out:
#               age        salary  satisfaction
# count  100.000000     91.000000    100.000000
# mean    43.350000  51425.593407      2.927000
# std     14.904663  15200.525199      1.123114
# min     19.000000  20901.000000      1.100000
# 25%     31.750000  39870.500000      2.000000
# 50%     42.000000  50985.000000      3.100000
# 75%     57.000000  62100.500000      3.800000
# max     69.000000  94155.000000      5.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['salary'].plot(kind='hist', bins=20, title='salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['satisfaction'].plot(kind='hist', bins=20, title='satisfaction')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('index').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='age', y='salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='salary', y='satisfaction', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['salary'].plot(kind='line', figsize=(8, 4), title='salary')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8['satisfaction'].plot(kind='line', figsize=(8, 4), title='satisfaction')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_9['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_9, x='age', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_10['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_10, x='salary', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_11['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_11, x='satisfaction', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# #### 3. Handling Missing Values
#
# Identify missing data since it can affect analysis and modeling. Here, we check count of nulls and fill missing salary values with the median as a simple imputation.

# %%
print("Missing values in each column:", data.isnull().sum())
median_salary = data['salary'].median()
data['salary'].fillna(median_salary, inplace=True)
print("Missing values after imputation:", data.isnull().sum())
# Out:
# Missing values in each column: age             0
# salary          9
# department      0
# satisfaction    0
# dtype: int64
# Missing values after imputation: age             0
# salary          0
# department      0
# satisfaction    0
# dtype: int64
# /tmp/ipython-input-3745141188.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['salary'].fillna(median_salary, inplace=True)

# %% [markdown]
# #### 4. Visualizing Data
#
# Visualization aids understanding distributions and relationships. Histograms show numerical data spread; boxplots highlight group differences and outliers; scatter plots reveal correlations.

# %%
plt.figure(figsize=(6,4))
sns.histplot(data['age'], bins=15, kde=True)
plt.title('Age Distribution')
plt.show()

plt.figure(figsize=(6,4))
sns.boxplot(x='department', y='salary', data=data)
plt.title('Salary Distribution by Department')
plt.show()

plt.figure(figsize=(6,4))
sns.scatterplot(x='salary', y='satisfaction', hue='department', data=data)
plt.title('Satisfaction vs Salary')
plt.show()

# %% [markdown]
# #### 5. Feature Exploration
#
# Quantify relationships between numeric features using correlation coefficients to detect linear associations. Visualize these with a heatmap for an intuitive summary.

# %%
corr_matrix = data[['age', 'salary', 'satisfaction']].corr()
print(corr_matrix)

plt.figure(figsize=(5,4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
#                    age    salary  satisfaction
# age           1.000000 -0.119218     -0.134710
# salary       -0.119218  1.000000     -0.004059
# satisfaction -0.134710 -0.004059      1.000000

# %% [markdown]
# 6. Detecting and Handling Outliers
#
# Outliers can skew analysis and model performance. Visualization with boxplots helps identify outliers; statistical methods like IQR or Z-score can be applied to detect and optionally remove them.

# %%
# Boxplot to check outliers in salary
plt.figure(figsize=(6,4))
sns.boxplot(x=data['salary'])
plt.title('Boxplot to Detect Outliers in Salary')
plt.show()

# Removing outliers using IQR method
Q1 = data['salary'].quantile(0.25)
Q3 = data['salary'].quantile(0.75)
IQR = Q3 - Q1
filtered_data = data[(data['salary'] >= Q1 - 1.5 * IQR) & (data['salary'] <= Q3 + 1.5 * IQR)]
print(f"Data size before outlier removal: {data.shape}")
print(f"Data size after outlier removal: {filtered_data.shape}")
# Out:
# Data size before outlier removal: (100, 4)
# Data size after outlier removal: (99, 4)

# %% [markdown]
# #### 7. Checking for Duplicate Rows
#
# Duplicate records can bias results and waste resources. Identifying and removing duplicates ensures cleaner data.

# %%
duplicates = data.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

# Remove duplicates if any
data = data.drop_duplicates()
print(f"Data size after removing duplicates: {data.shape}")
# Out:
# Number of duplicate rows: 0
# Data size after removing duplicates: (100, 4)

# %% [markdown]
# #### 8. Feature Engineering Basics
#
# Creating or transforming features can improve model predictive power. This includes generating new features, encoding categorical variables, and feature scaling.

# %%
# Example: Creating a new feature - Age Group
data['age_group'] = pd.cut(data['age'], bins=[17, 30, 50, 70], labels=['Young', 'Mid-age', 'Senior'])

# Encoding categorical 'department' using one-hot encoding
department_dummies = pd.get_dummies(data['department'], prefix='dept')
data = pd.concat([data, department_dummies], axis=1)

# Scaling numeric features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data[['salary_scaled', 'satisfaction_scaled']] = scaler.fit_transform(data[['salary', 'satisfaction']])

# %%
data.head(10)
# Out:
#    age   salary department  satisfaction age_group  dept_HR  dept_Sales  \
# 0   56  21865.0       Tech           3.3    Senior    False       False
# 1   69  29498.0      Sales           1.4    Senior    False        True
# 2   46  59545.0      Sales           3.5   Mid-age    False        True
# 3   32  36399.0       Tech           5.0   Mid-age    False       False
# 4   60  57141.0         HR           1.6    Senior     True       False
# 5   25  69555.0         HR           3.1     Young     True       False
# 6   38  53174.0       Tech           4.5   Mid-age    False       False
# 7   56  58956.0         HR           4.0    Senior     True       False
# 8   36  36555.0       Tech           3.8   Mid-age    False       False
# 9   40  48320.0         HR           3.8   Mid-age     True       False
#
#    dept_Tech  salary_scaled  satisfaction_scaled
# 0       True      -2.047075             0.333785
# 1      False      -1.517779            -1.366462
# 2      False       0.565775             0.512759
# 3       True      -1.039242             1.855060
# 4      False       0.399074            -1.187489
# 5      False       1.259900             0.154812
# 6       True       0.123990             1.407626
# 7      False       0.524932             0.960193
# 8       True      -1.028424             0.781219
# 9      False      -0.212602             0.781219
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['age_group'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_44['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_45['salary'].plot(kind='hist', bins=20, title='salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_46['satisfaction'].plot(kind='hist', bins=20, title='satisfaction')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_47['salary_scaled'].plot(kind='hist', bins=20, title='salary_scaled')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_48.groupby('department').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_49.groupby('dept_HR').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_50.groupby('dept_Sales').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_51.groupby('dept_Tech').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_52.plot(kind='scatter', x='age', y='salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_53.plot(kind='scatter', x='salary', y='satisfaction', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_54.plot(kind='scatter', x='satisfaction', y='salary_scaled', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_55.plot(kind='scatter', x='salary_scaled', y='satisfaction_scaled', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_56['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_57['salary'].plot(kind='line', figsize=(8, 4), title='salary')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_58['satisfaction'].plot(kind='line', figsize=(8, 4), title='satisfaction')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_59['salary_scaled'].plot(kind='line', figsize=(8, 4), title='salary_scaled')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['dept_HR'].value_counts()
#     for x_label, grp in _df_60.groupby('department')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('department')
# _ = plt.ylabel('dept_HR')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['dept_Sales'].value_counts()
#     for x_label, grp in _df_61.groupby('dept_HR')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('dept_HR')
# _ = plt.ylabel('dept_Sales')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['dept_Tech'].value_counts()
#     for x_label, grp in _df_62.groupby('dept_Sales')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('dept_Sales')
# _ = plt.ylabel('dept_Tech')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_63['department'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_63, x='age', y='department', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_64['dept_HR'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_64, x='age', y='dept_HR', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_65['dept_Sales'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_65, x='age', y='dept_Sales', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_66['dept_Tech'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_66, x='age', y='dept_Tech', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# #### 9. Advanced Visualizations: Pairplot & Countplot
#
# Pairplots visualize feature interactions in multivariate data, and countplots summarize categorical distributions.

# %%
# Pairplot to visualize relationships and distributions
sns.pairplot(data[['age', 'salary', 'satisfaction', 'department']], hue='department')
plt.show()

# Countplot for categorical feature distribution
plt.figure(figsize=(6,4))
sns.countplot(x='age_group', data=data)
plt.title('Count of Age Groups')
plt.show()

# %% [markdown]
# #### 10. Checking Data Balance and Relationships
#
# For classification tasks or categorical targets, checking class balance is important; also explore bivariate relationships for insights.

# %%
# Example: Value counts for target or categorical variable
print(data['department'].value_counts())

# Crosstab and heatmap for two categorical features or target relationship
crosstab = pd.crosstab(data['age_group'], data['department'])
sns.heatmap(crosstab, annot=True, cmap='Blues', fmt='d')
plt.title('Age Group vs Department Crosstab Heatmap')
plt.show()
# Out:
# department
# HR       39
# Tech     31
# Sales    30
# Name: count, dtype: int64

# %% [markdown]
# - #### Summary and Key Observations

# %% [markdown]
# 1.Data Generation: Synthetic employee data is created with features like age, salary, department, and satisfaction.
#
# 2.Initial Inspection: Basic statistics and data types are reviewed, highlighting missing values and overall structure.
#
# 3.Missing Value Handling: finds and fills missing salary data using the median value, ensuring the dataset is complete for analysis.
#
# 4.Visualization: It uses histograms, boxplots, and scatter plots to explore feature distributions, relationships, and potential outliers.
